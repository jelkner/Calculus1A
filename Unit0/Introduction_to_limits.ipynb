# %%
from closer import *
import numpy
globals()['math'] = numpy

# %% [markdown]
# # Example
# Approaching x from left

# %%
# %matplotlib inline
import numpy
import matplotlib.pyplot as plt
x = numpy.linspace(0, 1, 1000, endpoint=False)
y = f(x)
plt.plot(x, y)

# %% [markdown]
# # Exercise
# Approaching x from right

# %%
# %matplotlib inline
import numpy
import matplotlib.pyplot as plt
x = numpy.linspace(2, 1, 1000, endpoint=False)
y = f(x)
plt.plot(x, y)

# %% [markdown]
# # ^. A few more limits

# %%
x = numpy.linspace(1, 0, 1000, endpoint=False)
y = g(x)
plt.plot(x, y)

# %%
x = numpy.linspace(-1, 0, 1000, endpoint=False)
y = g(x)
plt.plot(x, y)

# %%
x = numpy.linspace(-1, 0, 1000, endpoint=False)
y = h(x)
plt.plot(x, y)

# %%
x = numpy.linspace(1, 0, 1000, endpoint=False)
y = h(x)
plt.plot(x, y)
